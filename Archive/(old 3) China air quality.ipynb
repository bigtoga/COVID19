# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

plt.style.use('fivethirtyeight')

# %% [markdown]
# # Manual step: go download latest version of air quality data
# 1. Go to <a href="https://aqicn.org/data-platform/register/" target="_blank">AQIcn.org</a>
# 2. Scroll to "Free downloadable database"
# 3. Enter Wuhan and search
# 4. Scroll down and click the button under "Wuhan past 75 months daily average AQI"
# 5. Enter your details, agree to the EULA, and click Submit

# %%
# Download data: https://aqicn.org/data-platform/register/
df = pd.read_csv('data/wuhan-air-quality_20200319.csv', sep=r'\s*,\s*', header=0, encoding='ascii', engine='python')

# Convert to datetime
df['date'] =  pd.to_datetime(df['date'], format='%Y/%m/%d')

df = df.set_index('date')

# We care only about NO2 values by date
# https://earthobservatory.nasa.gov/images/146362/airborne-nitrogen-dioxide-plummets-over-china
# "The maps on this page show concentrations of nitrogen dioxide, a noxious gas emitted by motor vehicles, power plants, and industrial facilities. The maps above show NO2 values across China from January 1-20, 2020 (before the quarantine) and February 10-25 (during the quarantine)."
df = df.drop(df.columns[[0, 1, 2, 4, 5]], axis=1)

# Convert from multindex to columns
df.reset_index(inplace=True)  

print(df.shape)
print(df.dtypes)

# List columns, # of rows w non-null in each column, column data types 
df.info()
df.describe()

df.head()
# Out:
# (2145, 2)
# date    datetime64[ns]
# no2            float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2145 entries, 0 to 2144
# Data columns (total 2 columns):
# date    2145 non-null datetime64[ns]
# no2     2120 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 33.6 KB
#         date   no2
# 0 2020-03-02  10.0
# 1 2020-03-03  10.0
# 2 2020-03-04  15.0
# 3 2020-03-05  15.0
# 4 2020-03-06  12.0

# %%
# Do the column names actually have spaces in front of the name? Had that once...
print(df.columns.tolist())

df.index.names
df.nsmallest(5, "no2") 
df.nlargest(5, "no2")
# Out:
# ['date', 'no2']
#            date   no2
# 1599 2015-04-23  81.0
# 1677 2015-01-10  78.0
# 1678 2015-01-11  77.0
# 1631 2015-05-25  74.0
# 1983 2014-05-16  74.0

# %% [markdown]
# # Feature Engineering - add metadata

# %%
# Add year 
df['Year'] = pd.DatetimeIndex(df['date']).year

# Add feature for YYYY-MM
df['Month'] = df['date'].dt.to_period('M')
df['MonthName'] = df['date'].dt.strftime('%b')
df['MonthYear'] = df['date'].dt.strftime('%Y-%b')

# Add feature for week 
df['Week'] = df['date'].dt.to_period(freq = 'W')  

df['c'] = df['date'].dt.dayofyear 
df['DayOfWeek'] = df['date'].dt.dayofweek # 0 = Sunday 
df['Day'] = df['date'].dt.day_name()
df['_IsWeekend'] = np.where(df['Day'].isin(['Saturday', 'Sunday']), 1, 0) # Add a boolean column 

df = df.sort_values(['Year', 'DayOfYear'])
df.head()
# Out:
#            date   no2  Year    Month MonthName MonthYear  \
# 2144 2014-01-01  69.0  2014  2014-01       Jan  2014-Jan
# 2030 2014-01-02  70.0  2014  2014-01       Jan  2014-Jan
# 2031 2014-01-03  52.0  2014  2014-01       Jan  2014-Jan
# 2032 2014-01-04  50.0  2014  2014-01       Jan  2014-Jan
# 2033 2014-01-05  59.0  2014  2014-01       Jan  2014-Jan
#
#                        Week  DayOfYear  DayOfWeek        Day  _IsWeekend
# 2144  2013-12-30/2014-01-05          1          2  Wednesday           0
# 2030  2013-12-30/2014-01-05          2          3   Thursday           0
# 2031  2013-12-30/2014-01-05          3          4     Friday           0
# 2032  2013-12-30/2014-01-05          4          5   Saturday           1
# 2033  2013-12-30/2014-01-05          5          6     Sunday           1

# %% [markdown]
# # Look at the past 30 days only

# %%
day_of_year = datetime.now().timetuple().tm_yday
print(f'Today is the {day_of_year} day of 2020')
# Out:
# Today is the 79 day of 2020

# %%
df1 = df[(df["DayOfYear"] >= (day_of_year - 30)) & (df["DayOfYear"] < day_of_year)]

print(f'   ... looking at dates for day of year {day_of_year - 30} - {day_of_year}')

# Alternate:
months = ['Mar']
x = df.query("MonthName in @months")
x.head()
# Out:
#    ... looking at dates for day of year 49 - 79
#            date   no2  Year    Month MonthName MonthYear  \
# 2088 2014-03-01  19.0  2014  2014-03       Mar  2014-Mar
# 2089 2014-03-02  26.0  2014  2014-03       Mar  2014-Mar
# 2090 2014-03-03  34.0  2014  2014-03       Mar  2014-Mar
# 2091 2014-03-04  39.0  2014  2014-03       Mar  2014-Mar
# 2092 2014-03-05  37.0  2014  2014-03       Mar  2014-Mar
#
#                        Week  DayOfYear  DayOfWeek        Day  _IsWeekend
# 2088  2014-02-24/2014-03-02         60          5   Saturday           1
# 2089  2014-02-24/2014-03-02         61          6     Sunday           1
# 2090  2014-03-03/2014-03-09         62          0     Monday           0
# 2091  2014-03-03/2014-03-09         63          1    Tuesday           0
# 2092  2014-03-03/2014-03-09         64          2  Wednesday           0

# %%
df1.plot(
    x='MonthYear'
    , y='no2'
)

# %%
sns.lineplot(
    x="DayOfYear"
    , y="no2"
    , hue="Year"
    , ci = None # turn off error bars
    , data=df
)

# %%
sns.barplot(
    x="DayOfYear"
    , y="no2"
    , hue="Year"
    , data=df1
)
plt.title("no per day YOY")
plt.show()

# %%
sns.boxplot(x="date", y="no2", data=df1)
plt.title("no per day YOY")
plt.show()

# %%
sns.pointplot(x="date", y="no2", data=df)
plt.title("Confirmed Cases per Day")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f80c4c56e592> in <module>
# ----> 1 sns.pointplot(x="date", y="no2", data=df)
#       2 plt.title("Confirmed Cases per Day")
#       3 plt.show()
#
# D:\Anaconda3\lib\site-packages\seaborn\categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3338         ax = plt.gca()
#    3339
# -> 3340     plotter.plot(ax)
#    3341     return ax
#    3342
#
# D:\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax)
#    1809     def plot(self, ax):
#    1810         """Make the plot."""
# -> 1811         self.draw_points(ax)
#    1812         self.annotate_axes(ax)
#    1813         if self.orient == "h":
#
# D:\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_points(self, ax)
#    1755             ax.scatter(x, y,
#    1756                        linewidth=mew, marker=marker, s=markersize,
# -> 1757                        c=hex_colors, edgecolor=hex_colors)
#    1758
#    1759         else:
#
# D:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4488                 offsets=offsets,
#    4489                 transOffset=kwargs.pop('transform', self.transData),
# -> 4490                 alpha=alpha
#    4491                 )
#    4492         collection.set_transform(mtransforms.IdentityTransform())
#
# D:\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     881         """
#     882
# --> 883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
#     885         self.set_sizes(sizes)
#
# D:\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     126         self._hatch_color = mcolors.to_rgba(mpl.rcParams['hatch.color'])
#     127         self.set_facecolor(facecolors)
# --> 128         self.set_edgecolor(edgecolors)
#     129         self.set_linewidth(linewidths)
#     130         self.set_linestyle(linestyles)
#
# D:\Anaconda3\lib\site-packages\matplotlib\collections.py in set_edgecolor(self, c)
#     726         """
#     727         self._original_edgecolor = c
# --> 728         self._set_edgecolor(c)
#     729
#     730     def set_alpha(self, alpha):
#
# D:\Anaconda3\lib\site-packages\matplotlib\collections.py in _set_edgecolor(self, c)
#     710         except AttributeError:
#     711             pass
# --> 712         self._edgecolors = mcolors.to_rgba_array(c, self._alpha)
#     713         if set_hatch_color and len(self._edgecolors):
#     714             self._hatch_color = tuple(self._edgecolors[0])
#
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     284     result = np.empty((len(c), 4), float)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#     288
#
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# D:\Anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     236         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     237         # Test dimensionality to reject single floats.
# --> 238         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     239     # Return a tuple to prevent the cached value from being modified.
#     240     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: masked

# %%
# pip install plotly_express
import plotly.express as px
px.line(
    df1
    , x='DayOfYear'
    , y= 'no2'
    , color = 'Year'
)
